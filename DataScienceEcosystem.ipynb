# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. Java

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. Numpy
# 2. Pandas
# 3. Matplotlib

# %% [markdown]
# | Data Science Tools |
# | ------------------ |
# | Tableau |
# | Power BI |
# | Excel |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.

# %%
 # This a simple arithmetic expression to mutiply then add integers
result = (3*4)+5
print(result)
# Out:
# Running cells with 'c:\Users\11015\AppData\Local\Programs\Python\Python312\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/11015/AppData/Local/Programs/Python/Python312/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
# This will convert 200 minutes to hours by diving by 60
hours = 200 / 60
print(hours)
# Out:
# Running cells with 'c:\Users\11015\AppData\Local\Programs\Python\Python312\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/11015/AppData/Local/Programs/Python/Python312/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# **Objectives:**
#
# - Listing popular languages for Data Science
# - Evaluating simple arithmetic expressions
# - Writing an expression to convert minutes to hours
# - Basics of using Markdown, such as creating tables and unordered lists
# - Creation and execution of Python code cells

# %% [markdown]
# ## Author
# Ethan Huang
